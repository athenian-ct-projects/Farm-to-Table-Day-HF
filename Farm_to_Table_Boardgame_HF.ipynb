# %% [markdown]
# <a href="https://colab.research.google.com/github/athenian-ct-projects/Farm-to-Table-HF/blob/master/Farm_to_Table_Boardgame_HF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Farm to Table Triva Board Game Code
#
# by: Hunter F '23
#
# Be sure to get the game board that goes with this game!

# %%
#food trivia game
import random

class QA:
  def __init__(self, question, correctAnswer, otherAnswers):
    self.question = question
    self.corrAnsw = correctAnswer
    self.otherAnsw = otherAnswers
#these are the questions you are asked and then the answer is after that and then after the true answer are the "distration answers"
qaList = [QA("What is the largest type of olive tree called?", "donkey olive", ["ancient olive", "bullet", "horse olive"]),
QA("How many types of apples are there around the world?", "7,000", ["2,000", "9,000", "5,500"]),
QA("Besides vanilla, what spice is the most expensive?", "saffron", ["ginger", "cinnamon", "cardamom"]),
QA("What does the name for pomegranate mean?", "apple with many seeds", ["big red fruit", "round strawberry","red peach with a crown"]),
QA("Cranberrys that are good and ripe will bounce. So, a common nickname for them is what?", "Bounceberry", ["floatberry", "boingfruit", "bouncefruit"]),
QA("The science of apple growing is called what?", "pomology", ["apple chemistry", "applelogy", "blossom science"]),
QA("Vanilla is the only fruit-bearing member of what family?", "orchid family", ["pod family", "blossom family", "bean family"]),
QA("How long can pomegranate trees live up to?", "200 years", ["300 years", "100 years", "50 years"]),
QA("How many liters of olives does it take to make one liter of olive oil?", "7 liters", ["8 liters", "10 liters", "3 liters"]),
QA("An apple floats, because what percentage of it's volume is air?", "25%", ["50%", "75%", "35%"]),
QA("What percentage of cranberries are almost all water?", "90%", ["50%", "40%", "70%"]),
QA("Only one type of bee can pollinate vanilla in Central America. What is that bee?", "melipona bee", ["bumble bee", "carpenter bee", "honey bee"]),
QA("The flower that produces the vanilla bean lasts how many days?", "one day", ["three days", "one week", "two days"]),
QA("Pomegranates grown in the United States are typically grown in what months?", "September to Decemeber", ["Febuary to April", "June to September", "Septemeber to October"]),
QA("Apples are apart of what family?", "rose family", ["branch family", "red family", "seed family"]),
QA("Americans consume how many gallons of jellied cranberry sauce every holiday season?", "5,062,500", ["6,062,500", "3,062,500", "2,050,120"]),
QA("How many cranberries does it take to make one can of cranberry jelly?", "200", ["300", "450", "100"]),
QA("What type of climates are pomegranates typically grown in?", "hot and dry", ["cold and wet", "humid", "dry and cold"]),
QA("In ancient Greece, tossing an apple to a girl was a traditional proposal of what? Catching it was her acceptance.", "marriage", ["forgiveness", "to go on a trip", "that we only eat apples for the rest of our lives"]),
QA("Nearly what percentage of Americans choose vanilla as their No. 1 ice cream flavor?", "30%", ["40%", "25%", "10%"])]
#code to help them make sure they pick an answer and dont make a typo 
#tells them is answer is correct or incorrect
corrCount = 0
random.shuffle(qaList)
for qaItem in qaList:
  print(qaItem.question)
  print("Possible answers are:")
  possible = qaItem.otherAnsw + [qaItem.corrAnsw] 
  random.shuffle(possible)
  count = 0 
  while count < len(possible):
    print(str(count+1) + ": " + possible[count])
    count += 1
  print("Please enter the number of your answer:")
  userAnsw = input()
  while not userAnsw.isdigit():
    print("That was not a number. Please enter the number of your answer:")
    userAnsw = input()
  userAnsw = int(userAnsw)
  while not (userAnsw > 0 and userAnsw <= len(possible)):
    print("That number doesn't correspond to any answer. Please enter the number of your answer:")
    userAnsw = input()
  if possible[userAnsw-1] == qaItem.corrAnsw:
    print("Your answer was correct.")
    corrCount += 1
  else:
    print("Your answer was wrong.")
    print("Correct answer was: " + qaItem.corrAnsw)
  print("")

print("You answered " + str(corrCount) + " of " + str(len(qaList)) + " questions correctly.")
# Out:
# Apples are apart of what family?
# Possible answers are:
# 1: branch family
# 2: rose family
# 3: seed family
# 4: red family
# Please enter the number of your answer:
# 2
# Your answer was correct.
#
# Vanilla is the only fruit-bearing member of what family?
# Possible answers are:
# 1: orchid family
# 2: bean family
# 3: blossom family
# 4: pod family
# Please enter the number of your answer:
# 1
# Your answer was correct.
#
# What does the name for pomegranate mean?
# Possible answers are:
# 1: apple with many seeds
# 2: red peach with a crown
# 3: round strawberry
# 4: big red fruit
# Please enter the number of your answer:
# 1
# Your answer was correct.
#
# In ancient Greece, tossing an apple to a girl was a traditional proposal of what? Catching it was her acceptance.
# Possible answers are:
# 1: marriage
# 2: that we only eat apples for the rest of our lives
# 3: forgiveness
# 4: to go on a trip
# Please enter the number of your answer:
# 1
# Your answer was correct.
#
# How many liters of olives does it take to make one liter of olvie oil?
# Possible answers are:
# 1: 7 liters
# 2: 10 liters
# 3: 8 liters
# 4: 3 liters
# Please enter the number of your answer:
# 1
# Your answer was correct.
#
# Americans consume how many gallons of jellied cranberry sauce every holiday season?
# Possible answers are:
# 1: 5,062,500
# 2: 3,062,500
# 3: 2,050,120
# 4: 6,062,500
# Please enter the number of your answer:
# 2
# Your answer was wrong.
# Correct answer was: 5,062,500
#
# Besides vanilla what spice is the most expensive?
# Possible answers are:
# 1: saffron
# 2: cardamom
# 3: cinnamon
# 4: ginger
# Please enter the number of your answer:
# 2
# Your answer was wrong.
# Correct answer was: saffron
#
# How many cranberries does it take to make one can of cranberry jelly?
# Possible answers are:
# 1: 300
# 2: 100
# 3: 200
# 4: 450
# Please enter the number of your answer:
# 3
# Your answer was correct.
#
# What percentage of cranberries are almost all water?
# Possible answers are:
# 1: 70%
# 2: 90%
# 3: 40%
# 4: 50%
# Please enter the number of your answer:
# 4
# Your answer was wrong.
# Correct answer was: 90%
#
# Only one type of bee and pollinate vanilla in Central America. What is that bee?
# Possible answers are:
# 1: honey bee
# 2: melipona bee
# 3: bumble bee
# 4: carpenter bee
# Please enter the number of your answer:
# 2
# Your answer was correct.
#
# The flower that produces the vanilla bean lasts how many days?
# Possible answers are:
# 1: one week
# 2: three days
# 3: one day
# 4: two days
# Please enter the number of your answer:
# 2
# Your answer was wrong.
# Correct answer was: one day
#
# The science of apple growing is called what?
# Possible answers are:
# 1: applelogy
# 2: blossom science
# 3: apple chemistry
# 4: pomology
# Please enter the number of your answer:
# 4
# Your answer was correct.
#
# Cranberrys that are good and ripe will bounce. So, a common nickname for them is what?
# Possible answers are:
# 1: boingfruit
# 2: floatberry
# 3: Bounceberry
# 4: bouncefruit
# Please enter the number of your answer:
# 3
# Your answer was correct.
#
# What type of climates are pomegranates typically grown in?
# Possible answers are:
# 1: hot and dry
# 2: humid
# 3: dry and cold
# 4: cold and wet
# Please enter the number of your answer:
# 1
# Your answer was correct.
#
# How long can pomegranate trees live up to?
# Possible answers are:
# 1: 100 years
# 2: 50 years
# 3: 300 years
# 4: 200 years
# Please enter the number of your answer:
# 1
# Your answer was wrong.
# Correct answer was: 200 years
#
# What is the largest type of olive tree called?
# Possible answers are:
# 1: bullet
# 2: donkey olive
# 3: ancient olive
# 4: horse olive
# Please enter the number of your answer:
# 3
# Your answer was wrong.
# Correct answer was: donkey olive
#
# Pomegranates grown in the United States are typically grown in what months?
# Possible answers are:
# 1: Febuary to April
# 2: Septemeber to October
# 3: June to September
# 4: September to Decemeber
# Please enter the number of your answer:
# 3
# Your answer was wrong.
# Correct answer was: September to Decemeber
#
# An apple floats, because what percentage of it's volume is air?
# Possible answers are:
# 1: 50%
# 2: 35%
# 3: 25%
# 4: 75%
# Please enter the number of your answer:
# 2
# Your answer was wrong.
# Correct answer was: 25%
#
# How many types of apples are there around the world?
# Possible answers are:
# 1: 7,000
# 2: 5,500
# 3: 2,000
# 4: 9,000
# Please enter the number of your answer:
# 4
# Your answer was wrong.
# Correct answer was: 7,000
#
# Nearly what percentage of Americans choose vanilla as their No. 1 ice cream flavor?
# Possible answers are:
# 1: 25%
# 2: 30%
# 3: 10%
# 4: 40%
# Please enter the number of your answer:
# 2
# Your answer was correct.
#
# You answered 11 of 20 questions correctly.

# %%
#code that acts like a die (1-6)
x = "*To roll again enter Y and to stop rolling enter N*"
print(x)
import random
repeat = True
while repeat:
    print("You rolled",random.randint(1,6))
    print("Do you want to roll again? Y/N")
    repeat = "Y" in input()

# %% [markdown]
# *If you don't have a die with you then use this one*

# %% [markdown]
# References:
#
# * Vanilla: https://www.webmd.com/food-recipes/features/vanilla-8-facts
# * Apples: http://www.gardenersnet.com/fun/apple-trivia.htm
# * Pomegranate: https://thatsitfruit.com/blog/10-interesting-facts-about-pomegranates/
# * Cranberry: http://www.foodreference.com/html/fcranberries.html
# * Olive: https://olivegevity.com/olive-trivia-42-interesting-facts/
